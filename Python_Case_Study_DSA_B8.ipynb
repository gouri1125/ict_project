# %% [markdown]
# <a href="https://colab.research.google.com/github/gouri1125/ict_project/blob/main/Python_Case_Study_DSA_B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Answer the following questions using only builtin Python datatypes and functions. Do not use Numpy or Scipy (i.e. No library imports allowed)

# %% [markdown]
# # Q1. Write a function that return the range (maximum and minimun) of a given list of numbers

# %%
list1=[100,22,33,44,55,66,77]
def find_range(number):
  min_value=list1[0]
  max_value=list1[0]
  for i in list1:
    if min_value >= list1[1]:
      min_value = i
    if max_value <= list1[1]:
      max_value = i
  return(min_value,max_value)


range = find_range(list1)
print("the range min and max is:",range)
# Out:
# the range min and max is: (77, 100)

# %% [markdown]
# ## Q2. Write function that returns mean value of a list of numbers

# %%
list2=[11,21,31,41,51,61,71]
def meann(fun_call):
  total=0
  for i in list2:
    total += i
  mean_value= total /len(list2)
  return mean_value


rn=meann(list2)
print("the mean value of the list is:",rn)
# Out:
# the mean value of the list is: 41.0

# %% [markdown]
# # Q3. Write a function that returns the median value of a list of numbers

# %%
list3=[11,21,31,99,51,101,71]

def mediann(num):
  print("sorted list",sorted(list3))

  list_length = len(list3)
  print(list_length)

  if list_length % 2 == 0:
    mid = list_length // 2
    median1= sorted[mid - 1] + sorted[mid] / 2
    print("meadian value: ",median1)
  else:
    mid = list_length//2
    median1= sorted[mid]
    print(median1)

mediann(list3)
# Out:
# sorted list [11, 21, 31, 51, 71, 99, 101]
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2489537557.py in <cell line: 0>()
#      16     print(median1)
#      17
# ---> 18 mediann(list3)
#
# /tmp/ipython-input-2489537557.py in mediann(num)
#      13   else:
#      14     mid = list_length//2
# ---> 15     median1= sorted[mid]
#      16     print(median1)
#      17
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# ## Q4. Write a function to return the mod of a list of numbers, if no mod exists, it should return None. If more than one mod exist, return the mod values as list

# %%
from ast import Index
list3=[11,21,31,41,51,61,71]
def mediann(fun_call):
  median_value=list3.index(41)
  print("the median value of the list is:",median_value)
mediann(list3)
# Out:
# the median value of the list is: 3

# %% [markdown]
# ## Q5. Write function to compute a given percentile value (e.g. 90th percentile) of a list of numbers

# %% [markdown]
# # Q6. Write a function that returns the lower bound of a list of numbers

# %% [markdown]
# ## Q7. Write function to return any outliers from a given list of numbers, if no outliers present it should return None

# %% [markdown]
# ##Q8. Write a function to return standard deviation of a list of numbers

# %% [markdown]
# ## Q9. Write function to compute and return Z-score values of a list of numbers

# %% [markdown]
# ## Q10. Write a function to compute and return the Pearson correlation coefficient value of two list of numbers
